# %% [markdown]
# **GROUP 17 - DATAVERSE INTERNSHIP DATAGAP INITIATIVE DATA ANALYSIS**

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import  matplotlib.pyplot as plt

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# Defining file path
path = '/content/drive/MyDrive/Colab Notebooks/Dataverse Internship Datagap Task 1/group17_Datagap Dataset2.xlsx'

# %%
data = pd.read_excel(path, sheet_name='Sheet1')
#Viewing first 5 rows of the dataset
data.head()
# Out:
#        Domain             Sub_Domain   Data Type  \
# 0  Healthcare   Disease Surveillance  Structured
# 1  Healthcare  Healthcare Management  Structured
# 2  Healthcare  Healthcare Management  Structured
# 3  Healthcare   Disease Surveillance  Structured
# 4  Healthcare          Public Health  Structured
#
#                               Data Source Data Availability Data Quality  \
# 0  WHO Global Health Expenditure Database          Abundant         High
# 1  WHO Global Health Expenditure Database          Abundant         High
# 2  WHO Global Health Expenditure Database          Abundant         High
# 3                           WHO AFRO iAHO          Abundant         High
# 4                           WHO AFRO iAHO          Moderate         High
#
#   Data Format             Access Constraints Update Frequency  \
# 0         CSV  Restricted (sign-up required)         Annually
# 1         CSV  Restricted (sign-up required)         Annually
# ...

# %%
#View basic information about the dataset
print(data.info())
print(data.head())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 16 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Domain              100 non-null    object
#  1   Sub_Domain          100 non-null    object
#  2   Data Type           100 non-null    object
#  3   Data Source         100 non-null    object
#  4   Data Availability   100 non-null    object
#  5   Data Quality        100 non-null    object
#  6   Data Format         100 non-null    object
#  7   Access Constraints  100 non-null    object
#  8   Update Frequency    100 non-null    object
#  9   Data Standard       100 non-null    object
#  10  Gap Analysis        100 non-null    object
#  11  Geographic Scope    100 non-null    object
#  12  Temporal Scope      100 non-null    object
#  13  Data Governance     100 non-null    object
#  14  Interoperability    100 non-null    object
# ...

# %%
#Check for missing values
missing_values = data.isnull().sum()
print("\nMissing Values in Dataset:\n", missing_values)
# Out:
# Missing Values in Dataset:
#  Domain                0
# Sub_Domain            0
# Data Type             0
# Data Source           0
# Data Availability     0
# Data Quality          0
# Data Format           0
# Access Constraints    0
# Update Frequency      0
# Data Standard         0
# Gap Analysis          0
# Geographic Scope      0
# Temporal Scope        0
# Data Governance       0
# Interoperability      0
# Data link             4
# dtype: int64

# %%
# Step 5: Data Availability Analysis
availability_counts = data["Data Availability"].value_counts()
plt.figure(figsize=(8,5))
sns.barplot(x=availability_counts.index, y=availability_counts.values, palette="coolwarm")
plt.title("Data Availability Across Datasets")
plt.xlabel("Availability Level")
plt.ylabel("Count")
plt.show()
# Out:
# <ipython-input-18-2b5cfd4294e7>:4: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=availability_counts.index, y=availability_counts.values, palette="coolwarm")

# %%
availability_count = data['Data Availability'].value_counts()

# Step 2: Plot the Pie Chart
plt.figure(figsize=(8, 8))
plt.pie(availability_count, labels=availability_count.index, autopct='%1.1f%%',
        colors=['#ff9999','#66b3ff','#99ff99','#ffcc99','#c2c2f0','#ffb3e6'],
        startangle=140, wedgeprops={'edgecolor': 'black'})

# Step 3: Add Title and Display Chart
plt.title("Data Availability Across Datasets")
plt.axis('equal')  # Ensures pie chart is a circle
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Data Quality Analysis - Using Histogram
plt.figure(figsize=(8,5))
sns.histplot(data["Data Quality"], bins=10, kde=False, color="royalblue")

# Chart Labels
plt.title("Data Quality Distribution Across All Domains", fontsize=14)
plt.xlabel("Data Quality Score", fontsize=12)
plt.ylabel("Frequency", fontsize=12)
plt.grid(axis="y", linestyle="--", alpha=0.7)

# Show the chart
plt.show()

# %%
 #Data Gaps by Domain
plt.figure(figsize=(10,5))
sns.countplot(y=data["Domain"], hue=data["Gap Analysis"], palette="magma")
plt.title("Data Gaps by Domain")
plt.xlabel("Count")
plt.ylabel("Healthcare Domain")
plt.legend(title="Issues Identified")
plt.show()

# %%
#Data Standard Issues
standard_issues = data["Data Standard"].value_counts()
plt.figure(figsize=(10,5))
sns.barplot(x=standard_issues.index, y=standard_issues.values)
plt.title("Data Standard Issues Across Domains")
plt.xlabel("Standard Issues")
plt.ylabel("Count")
plt.xticks(rotation=45)
plt.show()

# %%
import matplotlib.pyplot as plt

# Step 9: Count occurrences of each Geographic Scope category
geo_scope_counts = data["Geographic Scope"].value_counts()

# Step 10: Create Pie Chart
plt.figure(figsize=(8, 8))
plt.pie(geo_scope_counts, labels=geo_scope_counts.index, autopct='%1.1f%%',
        colors=['#ff9999','yellow','purple','#ffcc99','#c2c2f0','#ffb3e6'],
        startangle=140, wedgeprops={'edgecolor': 'black'})

# Step 11: Add Title and Display Chart
plt.title("Geographic Scope", fontsize=14)
plt.axis('equal')  # Ensures pie chart is a circle
plt.show()

# %%
# Step 8: Data Standard Issues
standard_issues = data["Access Constraints"].value_counts()
plt.figure(figsize=(10,5))
sns.barplot(x=standard_issues.index, y=standard_issues.values)
plt.title("Access Constraints Issues Across Domains")
plt.xlabel("Access Constraints")
plt.ylabel("Count")
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# **Healthcare Sector Insights**

# %%
import matplotlib.pyplot as plt
import seaborn as sns

healthcare_data = data[data["Domain"] == "Healthcare"]



# Count occurrences of each Data Availability category
availability_counts = healthcare_data["Data Availability"].value_counts()

# Plot a pie chart
plt.figure(figsize=(8, 6))
plt.pie(availability_counts, labels=availability_counts.index, autopct='%1.1f%%', startangle=140)
plt.title("Data Availability Across Healthcare Subdomains", fontsize=14)
plt.axis('equal')  # Equal aspect ratio ensures that pie chart is circular.
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Count occurrences of each Data Quality category
healthcare_data = data[data["Domain"] == "Healthcare"]
quality_counts = healthcare_data["Data Quality"].value_counts()

# Plot a horizontal bar chart
plt.figure(figsize=(10, 6))
sns.barplot(x=quality_counts.values, y=quality_counts.index, palette="viridis")
plt.title("Data Quality Distribution in Healthcare Datasets", fontsize=14)
plt.xlabel("Number of Datasets", fontsize=12)
plt.ylabel("Data Quality Level", fontsize=12)
plt.show()
# Out:
# <ipython-input-82-a02cf5a42784>:10: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=quality_counts.values, y=quality_counts.index, palette="viridis")

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Step 1: Filter the dataset to include only the 'Healthcare' domain
healthcare_data = data[data["Domain"] == "Healthcare"]

# Step 2: Create the countplot
plt.figure(figsize=(10,6))
sns.countplot(y=healthcare_data["Sub_Domain"], hue=healthcare_data["Data Availability"])

# Step 3: Add chart labels and title
plt.title("Healthcare Data Availability by Subdomain", fontsize=14)
plt.xlabel("Count of Datasets", fontsize=12)
plt.ylabel("Healthcare Subdomain", fontsize=12)
plt.legend(title="Data Availability")
plt.show()

# %%
import matplotlib.pyplot as plt

# Step 1: Filter the dataset to include only the 'Healthcare' domain
healthcare_data = data[data["Domain"] == "Healthcare"]

# Step 2: Count occurrences of each Access Constraint category in Healthcare
access_counts = healthcare_data["Access Constraints"].value_counts()

# Step 3: Plot a pie chart
plt.figure(figsize=(8, 8))
plt.pie(access_counts, labels=access_counts.index, autopct='%1.1f%%',
        colors=plt.cm.Set2.colors, startangle=140, wedgeprops={'edgecolor': 'black'})

# Step 4: Add title
plt.title("Access Constraints for Healthcare Datasets", fontsize=14)
plt.axis('equal')  # Ensures pie chart is circular
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Count occurrences of each Gap Analysis category
healthcare_data = data[data["Domain"] == "Healthcare"]
gap_counts = healthcare_data["Gap Analysis"].value_counts()

# Calculate percentages
total = gap_counts.sum()
percentages = (gap_counts / total) * 100

# Plot a horizontal bar chart
plt.figure(figsize=(10, 6))
ax = sns.barplot(y=gap_counts.index, x=gap_counts.values, palette="Reds_r")
plt.title("Most Common Data Gaps in Healthcare", fontsize=14)
plt.xlabel("Number of Datasets", fontsize=12)
plt.ylabel("Identified Gaps", fontsize=12)

# Annotate each bar with the percentage
for i in range(len(gap_counts)):
    ax.text(gap_counts.values[i], i, f'{percentages[i]:.1f}%', va='center')

plt.show()
# Out:
# <ipython-input-85-0c27bd14262b>:14: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   ax = sns.barplot(y=gap_counts.index, x=gap_counts.values, palette="Reds_r")
# <ipython-input-85-0c27bd14262b>:21: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   ax.text(gap_counts.values[i], i, f'{percentages[i]:.1f}%', va='center')

# %%
healthcare_data = data[data["Domain"] == "Healthcare"]
# Count occurrences of each Geographic Scope category
geo_scope_counts = healthcare_data["Geographic Scope"].value_counts()

# Plot a pie chart
plt.figure(figsize=(8,8))
plt.pie(geo_scope_counts, labels=geo_scope_counts.index, autopct='%1.1f%%',
        colors=["#ff9999","#66b3ff","#99ff99"], startangle=140, wedgeprops={'edgecolor': 'black'})

plt.title("Geographic Scope of Healthcare Data", fontsize=14)
plt.axis('equal')  # Ensures pie chart is circular
plt.show()

# %%
# Count occurrences of each Update Frequency category
update_counts = healthcare_data["Update Frequency"].value_counts()

# Plot a bar chart
plt.figure(figsize=(8,6))
sns.barplot(x=update_counts.index, y=update_counts.values, palette="coolwarm")
plt.title("Update Frequency of Healthcare Datasets", fontsize=14)
plt.xlabel("Update Frequency", fontsize=12)
plt.ylabel("Number of Datasets", fontsize=12)
plt.xticks(rotation=45)
plt.show()
# Out:
# <ipython-input-46-611bcdccea00>:6: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=update_counts.index, y=update_counts.values, palette="coolwarm")

# %% [markdown]
# **Education Domain**

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

# Filter for Education domain
education_data = data[data["Domain"] == "Education"]
# Ensure consistent formatting
data["Domain"] = data["Domain"].str.strip().str.lower()

# Filter for Education domain
education_data = data[data["Domain"] == "education"]  # Match the formatting

# Count occurrences of each Data Availability category and ensure all categories are represented
availability_counts = education_data["Data Availability"].value_counts()


# Define expected categories
expected_categories = ['Limited', 'Abundant', 'Moderate']  # Adjust as necessary based on your dataset

# Create a DataFrame to ensure all categories are included
availability_counts = availability_counts.reindex(expected_categories, fill_value=0)

import matplotlib.pyplot as plt
import seaborn as sns

# Assuming availability_counts has been defined and contains the counts
plt.figure(figsize=(8, 6))

# Define a custom palette with two colors
custom_colors = ['#FF5733', '#33FF57']  # Replace with your desired colors

# Create the bar plot using the custom colors
sns.barplot(x=availability_counts.index, y=availability_counts.values, palette=custom_colors)

plt.title("Data Availability Across Education Subdomains", fontsize=14)
plt.xlabel("Data Availability Level", fontsize=12)
plt.ylabel("Number of Datasets", fontsize=12)
plt.xticks(rotation=45)
plt.show()
# Out:
# <ipython-input-99-757e10ee919e>:33: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=availability_counts.index, y=availability_counts.values, palette=custom_colors)
# <ipython-input-99-757e10ee919e>:33: UserWarning:
# The palette list has fewer values (2) than needed (3) and will cycle, which may produce an uninterpretable plot.
#   sns.barplot(x=availability_counts.index, y=availability_counts.values, palette=custom_colors)

# %%
# Count occurrences of each Data Quality category

quality_counts = education_data["Data Quality"].value_counts()

# Plot a pie chart
plt.figure(figsize=(8,8))
plt.pie(quality_counts, labels=quality_counts.index, autopct='%1.1f%%',
        colors=["#ff9999","#66b3ff","#99ff99"], startangle=140, wedgeprops={'edgecolor': 'black'})

plt.title("Data Quality Distribution in Education Datasets")
plt.axis('equal')  # Ensures pie chart is circular
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns



# Step 2: Create the countplot
plt.figure(figsize=(10,6))
sns.countplot(y=education_data["Sub_Domain"], hue=education_data["Data Availability"], palette="magma")

# Step 3: Add chart labels and title
plt.title("Education Data Availability by Subdomain", fontsize=14)
plt.xlabel("Count of Datasets", fontsize=12)
plt.ylabel("Education Subdomain", fontsize=12)
plt.legend(title="Data Availability")
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns


# Step 2: Count occurrences of each Access Constraint category in Healthcare
access_counts = education_data["Access Constraints"].value_counts()

# Step 3: Plot a bar chart
plt.figure(figsize=(8,6))
sns.barplot(x=access_counts.index, y=access_counts.values, palette="Set2")

# Step 4: Add chart labels and title
plt.title("Access Constraints for Education Datasets", fontsize=14)
plt.xlabel("Access Type", fontsize=12)
plt.ylabel("Number of Datasets", fontsize=12)
plt.xticks(rotation=45)
plt.show()
# Out:
# <ipython-input-102-8672924dbdf8>:10: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=access_counts.index, y=access_counts.values, palette="Set2")

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Count occurrences of each Gap Analysis category
gap_counts = education_data["Gap Analysis"].value_counts()

# Define a custom palette with four colors
custom_colors = ['#FF5733', '#33FF57', '#3357FF', '#FFD700']  # Replace with your desired colors

# Plot a horizontal bar chart with the custom colors
plt.figure(figsize=(10, 6))
sns.barplot(y=gap_counts.index, x=gap_counts.values, palette=custom_colors)

plt.title("Most Common Data Gaps in Education", fontsize=14)
plt.xlabel("Number of Datasets", fontsize=12)
plt.ylabel("Identified Gaps", fontsize=12)
plt.show()
# Out:
# <ipython-input-112-86d54571113e>:12: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(y=gap_counts.index, x=gap_counts.values, palette=custom_colors)

# %%
# Count occurrences of each Geographic Scope category
geo_scope_counts = education_data["Geographic Scope"].value_counts()

# Plot a pie chart
plt.figure(figsize=(8,8))
plt.pie(geo_scope_counts, labels=geo_scope_counts.index, autopct='%1.1f%%',
        colors=["#ff9999","#66b3ff","#99ff99"], startangle=140, wedgeprops={'edgecolor': 'black'})

plt.title("Geographic Scope of Education Data", fontsize=14)
plt.axis('equal')  # Ensures pie chart is circular
plt.show()

# %%
# Count occurrences of each Update Frequency category
update_counts = education_data["Update Frequency"].value_counts()

# Plot a bar chart
plt.figure(figsize=(8,6))
sns.barplot(x=update_counts.index, y=update_counts.values, palette="coolwarm")
plt.title("Update Frequency of Education Datasets", fontsize=14)
plt.xlabel("Update Frequency", fontsize=12)
plt.ylabel("Number of Datasets", fontsize=12)
plt.xticks(rotation=45)
plt.show()
# Out:
# <ipython-input-105-1c3add574311>:6: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=update_counts.index, y=update_counts.values, palette="coolwarm")

# %% [markdown]
# **Infrastructure domai**n

# %%
import matplotlib.pyplot as plt
import seaborn as sns

infrastructure_data = data[data["Domain"] == "Infrastructure"]

# Count occurrences of each Data Availability category
availability_counts = infrastructure_data["Data Availability"].value_counts()

# Plot a bar chart
plt.figure(figsize=(8,6))
sns.barplot(x=availability_counts.index, y=availability_counts.values, palette="coolwarm")
plt.title("Data Availability Across Infrastructure Subdomains", fontsize=14)
plt.xlabel("Data Availability Level", fontsize=12)
plt.ylabel("Number of Datasets", fontsize=12)
plt.xticks(rotation=45)
plt.show()
# Out:
# <ipython-input-57-5a4421f94b63>:11: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=availability_counts.index, y=availability_counts.values, palette="coolwarm")

# %%
# Count occurrences of each Data Quality category

quality_counts = infrastructure_data["Data Quality"].value_counts()

# Plot a pie chart
plt.figure(figsize=(8,8))
plt.pie(quality_counts, labels=quality_counts.index, autopct='%1.1f%%',
        colors=["#ff9999","#66b3ff","#99ff99"], startangle=140, wedgeprops={'edgecolor': 'black'})

plt.title("Data Quality Distribution in Infrastructure Datasets")
plt.axis('equal')  # Ensures pie chart is circular
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns



# Step 2: Create the countplot
plt.figure(figsize=(10,6))
sns.countplot(y=infrastructure_data["Sub_Domain"], hue=infrastructure_data["Data Availability"], palette="magma")

# Step 3: Add chart labels and title
plt.title("Infrastructure Data Availability by Subdomain", fontsize=14)
plt.xlabel("Count of Datasets", fontsize=12)
plt.ylabel("Subdomain", fontsize=12)
plt.legend(title="Data Availability")
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns


# Step 2: Count occurrences of each Access Constraint category i
access_counts = infrastructure_data["Access Constraints"].value_counts()

# Step 3: Plot a bar chart
plt.figure(figsize=(8,6))
sns.barplot(x=access_counts.index, y=access_counts.values, palette="Set2")

# Step 4: Add chart labels and title
plt.title("Access Constraints for Infrastruture Datasets", fontsize=14)
plt.xlabel("Access Type", fontsize=12)
plt.ylabel("Number of Datasets", fontsize=12)
plt.xticks(rotation=45)
plt.show()

import matplotlib.pyplot as plt
import seaborn as sns

# Count occurrences of each Gap Analysis category
gap_counts = infrastructure_data["Gap Analysis"].value_counts()

# Calculate percentages
total = gap_counts.sum()
percentages = (gap_counts / total) * 100

# Plot a horizontal bar chart
plt.figure(figsize=(10, 6))
ax = sns.barplot(y=gap_counts.index, x=gap_counts.values, palette="Reds_r")
plt.title("Most Common Data Gaps in Infrastructure Domain", fontsize=14)
plt.xlabel("Number of Datasets", fontsize=12)
plt.ylabel("Identified Gaps", fontsize=12)

# Annotate each bar with the percentage
for i in range(len(gap_counts)):
    ax.text(gap_counts.values[i] + 0.2, i, f'{percentages[i]:.1f}%', va='center')

plt.show()


# Count occurrences of each Geographic Scope category
geo_scope_counts = infrastructure_data["Geographic Scope"].value_counts()

# Plot a pie chart
plt.figure(figsize=(8,8))
plt.pie(geo_scope_counts, labels=geo_scope_counts.index, autopct='%1.1f%%',
        colors=["#ff9999","#66b3ff","#99ff99"], startangle=140, wedgeprops={'edgecolor': 'black'})

plt.title("Geographic Scope of Infrastruture Data", fontsize=14)
plt.axis('equal')  # Ensures pie chart is circular
plt.show()
# Count occurrences of each Update Frequency category
update_counts = infrastructure_data["Update Frequency"].value_counts()

# Plot a bar chart
plt.figure(figsize=(8,6))
sns.barplot(x=update_counts.index, y=update_counts.values, palette="coolwarm")
plt.title("Update Frequency of Infrastructure Datasets", fontsize=14)
plt.xlabel("Update Frequency", fontsize=12)
plt.ylabel("Number of Datasets", fontsize=12)
plt.xticks(rotation=45)
plt.show()
# Out:
# <ipython-input-89-75457977b622>:10: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=access_counts.index, y=access_counts.values, palette="Set2")
# <ipython-input-89-75457977b622>:31: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   ax = sns.barplot(y=gap_counts.index, x=gap_counts.values, palette="Reds_r")
# <ipython-input-89-75457977b622>:38: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   ax.text(gap_counts.values[i] + 0.2, i, f'{percentages[i]:.1f}%', va='center')
# ...

# %% [markdown]
# **Agriculture Domain**

# %%
import matplotlib.pyplot as plt
import seaborn as sns

agriculture_data = data[data["Domain"] == "Agriculture"]

# Count occurrences of each Data Availability category
availability_counts = agriculture_data["Data Availability"].value_counts()

# Plot a bar chart
plt.figure(figsize=(8,6))
sns.barplot(x=availability_counts.index, y=availability_counts.values)
plt.title("Data Availability Across Agriculture Subdomains", fontsize=14)
plt.xlabel("Data Availability Level", fontsize=12)
plt.ylabel("Number of Datasets", fontsize=12)
plt.xticks(rotation=45)
plt.show()

# %%
# Count occurrences of each Data Quality category

quality_counts = agriculture_data["Data Quality"].value_counts()

# Plot a pie chart
plt.figure(figsize=(8,8))
plt.pie(quality_counts, labels=quality_counts.index, autopct='%1.1f%%',
        colors=["green","#66b3ff","#99ff99"], startangle=140, wedgeprops={'edgecolor': 'black'})

plt.title("Data Quality Distribution in Agriculture Datasets")
plt.axis('equal')  # Ensures pie chart is circular
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns



# Step 2: Create the countplot
plt.figure(figsize=(10,6))
sns.countplot(y=agriculture_data["Sub_Domain"], hue=agriculture_data["Data Availability"])

# Step 3: Add chart labels and title
plt.title("Agricultural Data Availability by Subdomain", fontsize=14)
plt.xlabel("Count of Datasets", fontsize=12)
plt.ylabel("Subdomain", fontsize=12)
plt.legend(title="Data Availability")
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns


# Step 2: Count occurrences of each Access Constraint category i
access_counts = agriculture_data["Access Constraints"].value_counts()

# Step 3: Plot a bar chart
plt.figure(figsize=(8,6))
sns.barplot(x=access_counts.index, y=access_counts.values, palette="Set2")

# Step 4: Add chart labels and title
plt.title("Access Constraints for Agriculture Datasets", fontsize=14)
plt.xlabel("Access Type", fontsize=12)
plt.ylabel("Number of Datasets", fontsize=12)
plt.xticks(rotation=45)
plt.show()
# Count occurrences of each Gap Analysis category

gap_counts = agriculture_data["Gap Analysis"].value_counts()

# Plot a horizontal bar chart
plt.figure(figsize=(10,6))
sns.barplot(y=gap_counts.index, x=gap_counts.values, palette="Reds_r")
plt.title("Most Common Data Gaps in Agriculture domain", fontsize=14)
plt.xlabel("Number of Datasets", fontsize=12)
plt.ylabel("Identified Gaps", fontsize=12)
plt.show()

# Count occurrences of each Geographic Scope category
geo_scope_counts = agriculture_data["Geographic Scope"].value_counts()

# Plot a pie chart
plt.figure(figsize=(8,8))
plt.pie(geo_scope_counts, labels=geo_scope_counts.index, autopct='%1.1f%%',
        colors=["#ff9999","red","#99ff99"], startangle=140, wedgeprops={'edgecolor': 'black'})

plt.title("Geographic Scope of Agriculture Data", fontsize=14)
plt.axis('equal')  # Ensures pie chart is circular
plt.show()
# Count occurrences of each Update Frequency category
update_counts = agriculture_data["Update Frequency"].value_counts()

# Plot a bar chart
plt.figure(figsize=(8,6))
sns.barplot(x=update_counts.index, y=update_counts.values)
plt.title("Update Frequency of Agriculture Datasets", fontsize=14)
plt.xlabel("Update Frequency", fontsize=12)
plt.ylabel("Number of Datasets", fontsize=12)
plt.xticks(rotation=45)
plt.show()


import matplotlib.pyplot as plt

# Count occurrences of each Update Frequency category
update_counts = agriculture_data["Update Frequency"].value_counts()

# Plot a pie chart
plt.figure(figsize=(8, 8))
plt.pie(update_counts, labels=update_counts.index, autopct='%1.1f%%',
        colors=plt.cm.Paired.colors, startangle=140, wedgeprops={'edgecolor': 'black'})

# Add title
plt.title("Update Frequency of Agriculture Datasets", fontsize=14)
plt.axis('equal')  # Ensures pie chart is circular
plt.show()
# Out:
# <ipython-input-90-fd66024813ee>:10: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=access_counts.index, y=access_counts.values, palette="Set2")
# <ipython-input-90-fd66024813ee>:24: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(y=gap_counts.index, x=gap_counts.values, palette="Reds_r")
